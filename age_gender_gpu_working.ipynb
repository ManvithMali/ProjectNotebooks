# %% [markdown]
# <a href="https://colab.research.google.com/github/ManvithMali/ProjectNotebooks/blob/main/age_gender_gpu_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/UTKFACE/UTKFace.tar.gz\ \(Unzipped\ Files\)
# %ls
# Out:
# /content/drive/MyDrive/UTKFACE/UTKFace.tar.gz (Unzipped Files)
# UTKFace/

# %%
dataset_folder_name = 'UTKFace'

TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198

dataset_dict = {
    'gender_id': {
        0: 'male',
        1: 'female'
    }
}

dataset_dict['gender_alias'] = dict((g, i) for i, g in dataset_dict['gender_id'].items())

# %%
import numpy as np 
import pandas as pd
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def parse_dataset(dataset_path, ext='jpg'):
    """
    Used to extract information about our dataset. It does iterate over all images and return a DataFrame with
    the data (age, gender and sex) of all files.
    """
    def parse_info_from_file(path):
        """
        Parse information from a single file
        """
        try:
            filename = os.path.split(path)[1]
            filename = os.path.splitext(filename)[0]
            age, gender, race, _ = filename.split('_')

            return int(age), dataset_dict['gender_id'][int(gender)]
        except Exception as ex:
            return None, None, None
        
    files = glob.glob(os.path.join(dataset_path, "*.%s" % ext))
    
    records = []
    for file in files:
        info = parse_info_from_file(file)
        records.append(info)
        
    df = pd.DataFrame(records)
    df.columns = ['age', 'gender', 'file']
    df['file'] = files    
    df = df.dropna()    
    return df

# %%
df = parse_dataset(dataset_folder_name)
df.head()
# Out:
#     age gender                                           file
# 0  32.0   male  UTKFace/32_0_2_20170116162124916.jpg.chip.jpg
# 1  55.0   male  UTKFace/55_0_0_20170120222656161.jpg.chip.jpg
# 2  62.0   male  UTKFace/62_0_0_20170111203239701.jpg.chip.jpg
# 3  12.0   male  UTKFace/12_0_0_20170110225348936.jpg.chip.jpg
# 4  60.0   male  UTKFace/60_0_0_20170117160020104.jpg.chip.jpg

# %%
import plotly.graph_objects as go
from IPython.display import display, Image

def plot_distribution(pd_series):
    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()
    
    pie_plot = go.Pie(labels=labels, values=counts, hole=.3)
    fig = go.Figure(data=[pie_plot])
    fig.update_layout(title_text='Distribution for %s' % pd_series.name)
        
    img_bytes = fig.to_image(format="png")
    display(Image(img_bytes))

# %%
import plotly.express as px
fig = px.histogram(df, x="age", nbins=20)
fig.update_layout(title_text='Age distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="22346451-4ec7-4f29-b687-f83981193135" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("22346451-4ec7-4f29-b687-f83981193135")) {
#                     Plotly.newPlot(
#                         '22346451-4ec7-4f29-b687-f83981193135',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "age=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 20, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [32.0, 55.0, 62.0, 12.0, 60.0, 12.0, 16.0, 46.0, 26.0, 14.0, 34.0, 25.0, 3.0, 1.0, 30.0, 32.0, 5.0, 40.0, 12.0, 28.0, 1.0, 44.0, 36.0, 25.0, 39.0, 21.0, 26.0, 30.0, 45.0, 2.0, 40.0, 32.0, 47.0, 58.0, 17.0, 85.0, 55.0, 70.0, 65.0, 35.0, 39.0, 45.0, 15.0, 1.0, 35.0, 35.0, 26.0, 1.0, 14.0, 88.0, 49.0, 42.0, 62.0, 24.0, 1.0, 4.0, 45.0, 26.0, 29.0, 31.0, 26.0, 16.0, 1.0, 76.0, 28.0, 16.0, 40.0, 64.0, 61.0, 32.0, 50.0, 35.0, 27.0, 27.0, 26.0, 2.0, 25.0, 1.0, 22.0, 26.0, 35.0, 34.0, 28.0, 57.0, 31.0, 26.0, 63.0, 52.0, 26.0, 26.0, 19.0, 26.0, 22.0, 38.0, 37.0, 30.0, 1.0, 13.0, 21.0, 36.0, 55.0, 28.0, 23.0, 32.0, 34.0, 29.0, 40.0, 32.0, 39.0, 9.0, 69.0, 38.0, 60.0, 52.0, 41.0, 46.0, 32.0, 53.0, 21.0, 1.0, 53.0, 42.0, 55.0, 24.0, 30.0, 26.0, 23.0, 35.0, 26.0, 28.0, 27.0, 22.0, 50.0, 2.0, 24.0, 29.0, 20.0, 27.0, 1.0, 22.0, 21.0, 39.0, 31.0, 60.0, 14.0, 1.0, 30.0, 26.0, 8.0, 69.0, 3.0, 76.0, 26.0, 26.0, 65.0, 54.0, 55.0, 51.0, 20.0, 24.0, 28.0, 37.0, 40.0, 22.0, 32.0, 28.0, 30.0, 28.0, 50.0, 1.0, 29.0, 54.0, 4.0, 52.0, 82.0, 45.0, 22.0, 3.0, 26.0, 35.0, 28.0, 27.0, 85.0, 58.0, 16.0, 26.0, 35.0, 26.0, 26.0, 75.0, 16.0, 39.0, 23.0, 30.0, 65.0, 26.0, 26.0, 13.0, 21.0, 41.0, 24.0, 27.0, 24.0, 1.0, 55.0, 21.0, 18.0, 49.0, 20.0, 18.0, 48.0, 29.0, 24.0, 17.0, 29.0, 42.0, 46.0, 26.0, 47.0, 31.0, 39.0, 27.0, 41.0, 3.0, 2.0, 17.0, 16.0, 24.0, 88.0, 66.0, 70.0, 59.0, 1.0, 32.0, 35.0, 55.0, 54.0, 3.0, 52.0, 24.0, 54.0, 52.0, 67.0, 21.0, 21.0, 26.0, 24.0, 54.0, 38.0, 17.0, 1.0, 29.0, 54.0, 27.0, 35.0, 28.0, 80.0, 76.0, 9.0, 60.0, 75.0, 28.0, 72.0, 10.0, 27.0, 65.0, 24.0, 3.0, 32.0, 60.0, 5.0, 40.0, 58.0, 25.0, 29.0, 40.0, 23.0, 3.0, 3.0, 29.0, 35.0, 1.0, 22.0, 30.0, 55.0, 10.0, 25.0, 54.0, 30.0, 1.0, 35.0, 25.0, 64.0, 45.0, 26.0, 58.0, 26.0, 36.0, 36.0, 25.0, 39.0, 8.0, 26.0, 52.0, 28.0, 19.0, 35.0, 2.0, 85.0, 20.0, 28.0, 24.0, 68.0, 22.0, 27.0, 34.0, 20.0, 29.0, 37.0, 32.0, 40.0, 26.0, 63.0, 7.0, 1.0, 50.0, 61.0, 51.0, 45.0, 40.0, 37.0, 5.0, 32.0, 35.0, 40.0, 52.0, 3.0, 59.0, 35.0, 100.0, 24.0, 26.0, 27.0, 27.0, 47.0, 4.0, 60.0, 47.0, 14.0, 29.0, 1.0, 1.0, 1.0, 38.0, 27.0, 19.0, 29.0, 26.0, 35.0, 24.0, 40.0, 29.0, 36.0, 69.0, 85.0, 90.0, 25.0, 29.0, 25.0, 22.0, 26.0, 31.0, 49.0, 44.0, 54.0, 52.0, 41.0, 1.0, 38.0, 26.0, 57.0, 45.0, 26.0, 54.0, 55.0, 60.0, 29.0, 48.0, 7.0, 23.0, 29.0, 28.0, 26.0, 36.0, 36.0, 39.0, 34.0, 21.0, 58.0, 24.0, 37.0, 3.0, 30.0, 39.0, 21.0, 40.0, 43.0, 23.0, 77.0, 36.0, 40.0, 29.0, 6.0, 24.0, 16.0, 36.0, 28.0, 35.0, 30.0, 14.0, 30.0, 58.0, 24.0, 16.0, 30.0, 12.0, 56.0, 72.0, 25.0, 76.0, 6.0, 35.0, 53.0, 1.0, 24.0, 57.0, 23.0, 45.0, 32.0, 70.0, 30.0, 18.0, 37.0, 35.0, 30.0, 36.0, 37.0, 15.0, 58.0, 26.0, 26.0, 10.0, 22.0, 26.0, 21.0, 28.0, 85.0, 54.0, 32.0, 58.0, 31.0, 40.0, 1.0, 30.0, 26.0, 89.0, 32.0, 37.0, 23.0, 38.0, 29.0, 38.0, 35.0, 29.0, 22.0, 77.0, 63.0, 19.0, 66.0, 48.0, 27.0, 32.0, 21.0, 20.0, 42.0, 26.0, 30.0, 82.0, 35.0, 35.0, 67.0, 54.0, 24.0, 24.0, 16.0, 28.0, 24.0, 25.0, 28.0, 22.0, 26.0, 24.0, 17.0, 60.0, 90.0, 3.0, 2.0, 25.0, 25.0, 54.0, 33.0, 20.0, 28.0, 18.0, 29.0, 65.0, 90.0, 54.0, 10.0, 35.0, 53.0, 8.0, 2.0, 35.0, 42.0, 14.0, 28.0, 1.0, 21.0, 29.0, 26.0, 83.0, 52.0, 26.0, 16.0, 31.0, 90.0, 40.0, 24.0, 47.0, 65.0, 33.0, 80.0, 35.0, 63.0, 26.0, 75.0, 63.0, 29.0, 22.0, 22.0, 26.0, 46.0, 27.0, 1.0, 51.0, 30.0, 26.0, 35.0, 47.0, 32.0, 24.0, 27.0, 28.0, 26.0, 1.0, 31.0, 1.0, 1.0, 90.0, 58.0, 53.0, 31.0, 15.0, 22.0, 25.0, 3.0, 25.0, 39.0, 54.0, 35.0, 61.0, 26.0, 32.0, 26.0, 28.0, 34.0, 45.0, 19.0, 51.0, 8.0, 73.0, 7.0, 32.0, 58.0, 55.0, 45.0, 67.0, 54.0, 60.0, 40.0, 26.0, 54.0, 42.0, 42.0, 9.0, 34.0, 1.0, 11.0, 26.0, 1.0, 26.0, 30.0, 30.0, 29.0, 35.0, 31.0, 53.0, 32.0, 61.0, 71.0, 8.0, 34.0, 70.0, 65.0, 16.0, 30. ...

# %%
bins = [0, 10, 20, 30, 40, 60, 80, np.inf]
names = ['<10', '10-20', '20-30', '30-40', '40-60', '60-80', '80+']

age_binned = pd.cut(df['age'], bins, labels=names)

# %%
from keras.utils import to_categorical
from PIL import Image

class UtkFaceDataGenerator():
    """
    Data generator for the UTKFace dataset. This class should be used when training our Keras multi-output model.
    """
    def __init__(self, df):
        self.df = df
        
    def generate_split_indexes(self):
        p = np.random.permutation(len(self.df))
        train_up_to = int(len(self.df) * TRAIN_TEST_SPLIT)
        train_idx = p[:train_up_to]
        test_idx = p[train_up_to:]

        train_up_to = int(train_up_to * TRAIN_TEST_SPLIT)
        train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]
        
        # converts alias to id
        self.df['gender_id'] = self.df['gender'].map(lambda gender: dataset_dict['gender_alias'][gender])
        #self.df['race_id'] = self.df['race'].map(lambda race: dataset_dict['race_alias'][race])

        self.max_age = self.df['age'].max()

        print(self.max_age)
        
        return train_idx, valid_idx, test_idx
    
    def preprocess_image(self, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im = Image.open(img_path)
        im = im.resize((IM_WIDTH, IM_HEIGHT))
        im = np.array(im) / 255.0
        
        return im
        
    def generate_images(self, image_idx, is_training, batch_size=16):
        """
        Used to generate a batch with images when training/testing/validating our Keras model.
        """
        
        # arrays to store our batched data
        images, ages, genders = [], [], []
        while True:
            for idx in image_idx:
                person = self.df.iloc[idx]
                
                age = person['age']
                gender = person['gender_id']
                file = person['file']
                
                im = self.preprocess_image(file)
                
                ages.append(age / self.max_age)
                genders.append(to_categorical(gender, len(dataset_dict['gender_id'])))
                images.append(im)
                
                # yielding condition
                if len(images) >= batch_size:
                    yield np.array(images), [np.array(ages), np.array(genders)]
                    images, ages, genders = [], [],  []
                    
            if not is_training:
                break
                
data_generator = UtkFaceDataGenerator(df)
train_idx, valid_idx, test_idx = data_generator.generate_split_indexes()
# Out:
# 116.0

# %%
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
import tensorflow as tf

class UtkMultiOutputModel():
    """
    Used to generate our multi-output model. This CNN contains three branches, one for age, other for 
    sex and another for race. Each branch contains a sequence of Convolutional Layers that is defined
    on the make_default_hidden_layers method.
    """
    def make_default_hidden_layers(self, inputs):
        """
        Used to generate a default set of hidden layers. The structure used in this network is defined as:
        
        Conv2D -> BatchNormalization -> Pooling -> Dropout
        """
        x = Conv2D(16, (3, 3), padding="same")(inputs)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(3, 3))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        return x

    def build_race_branch(self, inputs, num_races):
        """
        Used to build the race branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.
        """
        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(128)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(num_races)(x)
        x = Activation("softmax", name="race_output")(x)

        return x

    def build_gender_branch(self, inputs, num_genders=2):
        """
        Used to build the gender branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.
        """
        x = Lambda(lambda c: tf.image.rgb_to_grayscale(c))(inputs)

        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(128)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(num_genders)(x)
        x = Activation("sigmoid", name="gender_output")(x)

        return x

    def build_age_branch(self, inputs):   
        """
        Used to build the age branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.

        """
        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(128)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(1)(x)
        x = Activation("linear", name="age_output")(x)

        return x

    def assemble_full_model(self, width, height):
        """
        Used to assemble our multi-output model CNN.
        """
        input_shape = (height, width, 3)

        inputs = Input(shape=input_shape)

        age_branch = self.build_age_branch(inputs)

        gender_branch = self.build_gender_branch(inputs)

        model = Model(inputs=inputs,
                     outputs = [age_branch, gender_branch],
                     name="face_net")

        return model
    
model = UtkMultiOutputModel().assemble_full_model(IM_WIDTH, IM_HEIGHT)

# %%
# %matplotlib inline

from keras.utils import plot_model
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

plot_model(model, to_file='model.png')
img = mpimg.imread('model.png')

plt.figure(figsize=(40, 30))
plt.imshow(img)

# %%
model.summary()
# Out:
# Model: "face_net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 198, 198, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 198, 198, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 198, 198, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 198, 198, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 198, 198, 16) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 198, 198, 16) 64          activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 198, 198, 16) 64          activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 66, 66, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 66, 66, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 66, 66, 16)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 66, 66, 16)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 66, 66, 32)   4640        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 66, 66, 32)   4640        dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 66, 66, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 66, 66, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 66, 66, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 66, 66, 32)   128         activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 33, 33, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 33, 33, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 33, 33, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 33, 33, 32)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 33, 33, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 33, 33, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 33, 33, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 33, 33, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 33, 33, 32)   128         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 33, 33, 32)   128         activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           dropout_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1048704     flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1048704     flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128)          512         activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            258         dropout_7[0][0]
# __________________________________________________________________________________________________
# age_output (Activation)         (None, 1)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# gender_output (Activation)      (None, 2)            0           dense_3[0][0]
# ==================================================================================================
# Total params: 2,128,131
# Trainable params: 2,127,299
# Non-trainable params: 832
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam

init_lr = 1e-4
epochs = 100

opt = Adam(lr=init_lr, decay=init_lr / epochs)

model.compile(optimizer=opt, 
              loss={
                  'age_output': 'mse', 
                  'gender_output': 'binary_crossentropy'},
              loss_weights={
                  'age_output': 4., 
                  'gender_output': 0.1},
              metrics={
                  'age_output': 'mae', 
                  'gender_output': 'accuracy'})

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 32
valid_batch_size = 32
train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
valid_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./model_checkpoint", monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 362/362 [==============================] - 5565s 15s/step - loss: 11.5317 - age_output_loss: 2.8639 - gender_output_loss: 0.7613 - age_output_mae: 1.3166 - gender_output_accuracy: 0.6922 - val_loss: 29.1053 - val_age_output_loss: 7.2600 - val_gender_output_loss: 0.6536 - val_age_output_mae: 2.4530 - val_gender_output_accuracy: 0.7407
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 2/100
# 362/362 [==============================] - 62s 171ms/step - loss: 5.8906 - age_output_loss: 1.4597 - gender_output_loss: 0.5159 - age_output_mae: 0.9195 - gender_output_accuracy: 0.7975 - val_loss: 23.5163 - val_age_output_loss: 5.8638 - val_gender_output_loss: 0.6107 - val_age_output_mae: 1.5787 - val_gender_output_accuracy: 0.8196
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 3/100
# 362/362 [==============================] - 62s 171ms/step - loss: 4.6679 - age_output_loss: 1.1558 - gender_output_loss: 0.4471 - age_output_mae: 0.8058 - gender_output_accuracy: 0.8173 - val_loss: 18.0933 - val_age_output_loss: 4.5033 - val_gender_output_loss: 0.8025 - val_age_output_mae: 0.9730 - val_gender_output_accuracy: 0.8131
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 4/100
# 362/362 [==============================] - 61s 168ms/step - loss: 3.5029 - age_output_loss: 0.8658 - gender_output_loss: 0.3976 - age_output_mae: 0.7048 - gender_output_accuracy: 0.8446 - val_loss: 19.1657 - val_age_output_loss: 4.7703 - val_gender_output_loss: 0.8448 - val_age_output_mae: 0.9551 - val_gender_output_accuracy: 0.8020
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 5/100
# 362/362 [==============================] - 61s 170ms/step - loss: 2.7580 - age_output_loss: 0.6800 - gender_output_loss: 0.3786 - age_output_mae: 0.6227 - gender_output_accuracy: 0.8442 - val_loss: 21.0055 - val_age_output_loss: 5.2342 - val_gender_output_loss: 0.6854 - val_age_output_mae: 1.0080 - val_gender_output_accuracy: 0.8244
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 6/100
# 362/362 [==============================] - 61s 170ms/step - loss: 2.2372 - age_output_loss: 0.5504 - gender_output_loss: 0.3550 - age_output_mae: 0.5542 - gender_output_accuracy: 0.8574 - val_loss: 11.0812 - val_age_output_loss: 2.7556 - val_gender_output_loss: 0.5865 - val_age_output_mae: 0.6502 - val_gender_output_accuracy: 0.8325
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 7/100
# 362/362 [==============================] - 61s 170ms/step - loss: 1.7178 - age_output_loss: 0.4210 - gender_output_loss: 0.3375 - age_output_mae: 0.4882 - gender_output_accuracy: 0.8618 - val_loss: 5.9781 - val_age_output_loss: 1.4822 - val_gender_output_loss: 0.4941 - val_age_output_mae: 0.4766 - val_gender_output_accuracy: 0.8492
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 8/100
# 362/362 [==============================] - 61s 170ms/step - loss: 1.4293 - age_output_loss: 0.3491 - gender_output_loss: 0.3304 - age_output_mae: 0.4398 - gender_output_accuracy: 0.8661 - val_loss: 6.6449 - val_age_output_loss: 1.6491 - val_gender_output_loss: 0.4849 - val_age_output_mae: 0.4838 - val_gender_output_accuracy: 0.8456
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 9/100
# 362/362 [==============================] - 61s 170ms/step - loss: 1.1098 - age_output_loss: 0.2696 - gender_output_loss: 0.3156 - age_output_mae: 0.3874 - gender_output_accuracy: 0.8723 - val_loss: 7.4269 - val_age_output_loss: 1.8441 - val_gender_output_loss: 0.5031 - val_age_output_mae: 0.4975 - val_gender_output_accuracy: 0.8423
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 10/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.8561 - age_output_loss: 0.2064 - gender_output_loss: 0.3060 - age_output_mae: 0.3406 - gender_output_accuracy: 0.8719 - val_loss: 6.4121 - val_age_output_loss: 1.5903 - val_gender_output_loss: 0.5092 - val_age_output_mae: 0.4502 - val_gender_output_accuracy: 0.8536
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 11/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.7105 - age_output_loss: 0.1701 - gender_output_loss: 0.2993 - age_output_mae: 0.3031 - gender_output_accuracy: 0.8781 - val_loss: 10.0477 - val_age_output_loss: 2.4972 - val_gender_output_loss: 0.5884 - val_age_output_mae: 0.5543 - val_gender_output_accuracy: 0.8409
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 12/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.5376 - age_output_loss: 0.1272 - gender_output_loss: 0.2859 - age_output_mae: 0.2651 - gender_output_accuracy: 0.8844 - val_loss: 11.3666 - val_age_output_loss: 2.8282 - val_gender_output_loss: 0.5383 - val_age_output_mae: 0.5790 - val_gender_output_accuracy: 0.8472
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 13/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.4053 - age_output_loss: 0.0944 - gender_output_loss: 0.2754 - age_output_mae: 0.2310 - gender_output_accuracy: 0.8846 - val_loss: 6.3138 - val_age_output_loss: 1.5679 - val_gender_output_loss: 0.4209 - val_age_output_mae: 0.4231 - val_gender_output_accuracy: 0.8653
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 14/100
# 362/362 [==============================] - 61s 168ms/step - loss: 0.3196 - age_output_loss: 0.0732 - gender_output_loss: 0.2692 - age_output_mae: 0.2033 - gender_output_accuracy: 0.8893 - val_loss: 8.3805 - val_age_output_loss: 2.0875 - val_gender_output_loss: 0.3040 - val_age_output_mae: 0.5592 - val_gender_output_accuracy: 0.8821
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 15/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.2405 - age_output_loss: 0.0535 - gender_output_loss: 0.2663 - age_output_mae: 0.1747 - gender_output_accuracy: 0.8920 - val_loss: 5.4310 - val_age_output_loss: 1.3494 - val_gender_output_loss: 0.3325 - val_age_output_mae: 0.4060 - val_gender_output_accuracy: 0.8829
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 16/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.1974 - age_output_loss: 0.0429 - gender_output_loss: 0.2588 - age_output_mae: 0.1575 - gender_output_accuracy: 0.8918 - val_loss: 4.4999 - val_age_output_loss: 1.1172 - val_gender_output_loss: 0.3117 - val_age_output_mae: 0.3517 - val_gender_output_accuracy: 0.8833
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 17/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.1537 - age_output_loss: 0.0321 - gender_output_loss: 0.2514 - age_output_mae: 0.1382 - gender_output_accuracy: 0.9011 - val_loss: 4.4013 - val_age_output_loss: 1.0931 - val_gender_output_loss: 0.2908 - val_age_output_mae: 0.3432 - val_gender_output_accuracy: 0.8887
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 18/100
# 362/362 [==============================] - 61s 168ms/step - loss: 0.1335 - age_output_loss: 0.0272 - gender_output_loss: 0.2492 - age_output_mae: 0.1268 - gender_output_accuracy: 0.8975 - val_loss: 4.1590 - val_age_output_loss: 1.0327 - val_gender_output_loss: 0.2810 - val_age_output_mae: 0.3290 - val_gender_output_accuracy: 0.8877
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 19/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.1146 - age_output_loss: 0.0226 - gender_output_loss: 0.2426 - age_output_mae: 0.1155 - gender_output_accuracy: 0.8998 - val_loss: 3.7247 - val_age_output_loss: 0.9241 - val_gender_output_loss: 0.2823 - val_age_output_mae: 0.3029 - val_gender_output_accuracy: 0.8897
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 20/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.1021 - age_output_loss: 0.0196 - gender_output_loss: 0.2373 - age_output_mae: 0.1063 - gender_output_accuracy: 0.9014 - val_loss: 1.1762 - val_age_output_loss: 0.2863 - val_gender_output_loss: 0.3104 - val_age_output_mae: 0.1791 - val_gender_output_accuracy: 0.8817
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 21/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0939 - age_output_loss: 0.0179 - gender_output_loss: 0.2244 - age_output_mae: 0.1033 - gender_output_accuracy: 0.9116 - val_loss: 1.4995 - val_age_output_loss: 0.3676 - val_gender_output_loss: 0.2918 - val_age_output_mae: 0.1983 - val_gender_output_accuracy: 0.8929
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 22/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0896 - age_output_loss: 0.0166 - gender_output_loss: 0.2298 - age_output_mae: 0.0994 - gender_output_accuracy: 0.9086 - val_loss: 1.4204 - val_age_output_loss: 0.3484 - val_gender_output_loss: 0.2670 - val_age_output_mae: 0.1951 - val_gender_output_accuracy: 0.8891
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 23/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0852 - age_output_loss: 0.0157 - gender_output_loss: 0.2233 - age_output_mae: 0.0960 - gender_output_accuracy: 0.9109 - val_loss: 1.1599 - val_age_output_loss: 0.2835 - val_gender_output_loss: 0.2586 - val_age_output_mae: 0.1834 - val_gender_output_accuracy: 0.8917
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 24/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0827 - age_output_loss: 0.0154 - gender_output_loss: 0.2097 - age_output_mae: 0.0947 - gender_output_accuracy: 0.9180 - val_loss: 1.3755 - val_age_output_loss: 0.3372 - val_gender_output_loss: 0.2660 - val_age_output_mae: 0.2093 - val_gender_output_accuracy: 0.8889
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 25/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0809 - age_output_loss: 0.0151 - gender_output_loss: 0.2037 - age_output_mae: 0.0938 - gender_output_accuracy: 0.9186 - val_loss: 0.8193 - val_age_output_loss: 0.1983 - val_gender_output_loss: 0.2617 - val_age_output_mae: 0.1709 - val_gender_output_accuracy: 0.8909
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 26/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0793 - age_output_loss: 0.0147 - gender_output_loss: 0.2030 - age_output_mae: 0.0932 - gender_output_accuracy: 0.9170 - val_loss: 1.0176 - val_age_output_loss: 0.2480 - val_gender_output_loss: 0.2564 - val_age_output_mae: 0.1684 - val_gender_output_accuracy: 0.8931
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 27/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0760 - age_output_loss: 0.0140 - gender_output_loss: 0.1984 - age_output_mae: 0.0899 - gender_output_accuracy: 0.9215 - val_loss: 0.7893 - val_age_output_loss: 0.1911 - val_gender_output_loss: 0.2505 - val_age_output_mae: 0.1557 - val_gender_output_accuracy: 0.8960
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 28/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.0743 - age_output_loss: 0.0137 - gender_output_loss: 0.1956 - age_output_mae: 0.0895 - gender_output_accuracy: 0.9241 - val_loss: 0.5428 - val_age_output_loss: 0.1294 - val_gender_output_loss: 0.2522 - val_age_output_mae: 0.1237 - val_gender_output_accuracy: 0.8986
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 29/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0708 - age_output_loss: 0.0130 - gender_output_loss: 0.1878 - age_output_mae: 0.0867 - gender_output_accuracy: 0.9254 - val_loss: 0.4440 - val_age_output_loss: 0.1045 - val_gender_output_loss: 0.2610 - val_age_output_mae: 0.1180 - val_gender_output_accuracy: 0.8958
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 30/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0697 - age_output_loss: 0.0130 - gender_output_loss: 0.1756 - age_output_mae: 0.0871 - gender_output_accuracy: 0.9328 - val_loss: 0.4787 - val_age_output_loss: 0.1133 - val_gender_output_loss: 0.2568 - val_age_output_mae: 0.1248 - val_gender_output_accuracy: 0.8968
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 31/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0687 - age_output_loss: 0.0128 - gender_output_loss: 0.1736 - age_output_mae: 0.0864 - gender_output_accuracy: 0.9338 - val_loss: 0.7487 - val_age_output_loss: 0.1806 - val_gender_output_loss: 0.2621 - val_age_output_mae: 0.1301 - val_gender_output_accuracy: 0.8893
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 32/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0670 - age_output_loss: 0.0126 - gender_output_loss: 0.1642 - age_output_mae: 0.0852 - gender_output_accuracy: 0.9401 - val_loss: 0.3590 - val_age_output_loss: 0.0835 - val_gender_output_loss: 0.2507 - val_age_output_mae: 0.1058 - val_gender_output_accuracy: 0.8956
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 33/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0649 - age_output_loss: 0.0123 - gender_output_loss: 0.1584 - age_output_mae: 0.0838 - gender_output_accuracy: 0.9392 - val_loss: 0.4514 - val_age_output_loss: 0.1064 - val_gender_output_loss: 0.2591 - val_age_output_mae: 0.1209 - val_gender_output_accuracy: 0.8964
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 34/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0618 - age_output_loss: 0.0117 - gender_output_loss: 0.1502 - age_output_mae: 0.0822 - gender_output_accuracy: 0.9409 - val_loss: 0.3871 - val_age_output_loss: 0.0884 - val_gender_output_loss: 0.3358 - val_age_output_mae: 0.1018 - val_gender_output_accuracy: 0.8907
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 35/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0611 - age_output_loss: 0.0115 - gender_output_loss: 0.1500 - age_output_mae: 0.0816 - gender_output_accuracy: 0.9423 - val_loss: 0.2841 - val_age_output_loss: 0.0647 - val_gender_output_loss: 0.2544 - val_age_output_mae: 0.1021 - val_gender_output_accuracy: 0.8986
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 36/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0598 - age_output_loss: 0.0112 - gender_output_loss: 0.1487 - age_output_mae: 0.0809 - gender_output_accuracy: 0.9442 - val_loss: 0.4222 - val_age_output_loss: 0.0990 - val_gender_output_loss: 0.2626 - val_age_output_mae: 0.1202 - val_gender_output_accuracy: 0.8913
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 37/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0586 - age_output_loss: 0.0109 - gender_output_loss: 0.1498 - age_output_mae: 0.0800 - gender_output_accuracy: 0.9418 - val_loss: 0.4812 - val_age_output_loss: 0.1140 - val_gender_output_loss: 0.2505 - val_age_output_mae: 0.1132 - val_gender_output_accuracy: 0.9020
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 38/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0578 - age_output_loss: 0.0109 - gender_output_loss: 0.1402 - age_output_mae: 0.0792 - gender_output_accuracy: 0.9499 - val_loss: 0.2626 - val_age_output_loss: 0.0582 - val_gender_output_loss: 0.2965 - val_age_output_mae: 0.0953 - val_gender_output_accuracy: 0.8895
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 39/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0570 - age_output_loss: 0.0106 - gender_output_loss: 0.1447 - age_output_mae: 0.0788 - gender_output_accuracy: 0.9454 - val_loss: 0.3831 - val_age_output_loss: 0.0886 - val_gender_output_loss: 0.2880 - val_age_output_mae: 0.1222 - val_gender_output_accuracy: 0.8938
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 40/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0556 - age_output_loss: 0.0106 - gender_output_loss: 0.1304 - age_output_mae: 0.0785 - gender_output_accuracy: 0.9516 - val_loss: 0.2195 - val_age_output_loss: 0.0481 - val_gender_output_loss: 0.2723 - val_age_output_mae: 0.0903 - val_gender_output_accuracy: 0.8974
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 41/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0538 - age_output_loss: 0.0103 - gender_output_loss: 0.1249 - age_output_mae: 0.0773 - gender_output_accuracy: 0.9514 - val_loss: 0.3315 - val_age_output_loss: 0.0751 - val_gender_output_loss: 0.3108 - val_age_output_mae: 0.1475 - val_gender_output_accuracy: 0.8893
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 42/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0526 - age_output_loss: 0.0099 - gender_output_loss: 0.1312 - age_output_mae: 0.0762 - gender_output_accuracy: 0.9507 - val_loss: 0.3864 - val_age_output_loss: 0.0894 - val_gender_output_loss: 0.2887 - val_age_output_mae: 0.1407 - val_gender_output_accuracy: 0.8911
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 43/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0513 - age_output_loss: 0.0098 - gender_output_loss: 0.1200 - age_output_mae: 0.0753 - gender_output_accuracy: 0.9555 - val_loss: 0.6536 - val_age_output_loss: 0.1552 - val_gender_output_loss: 0.3288 - val_age_output_mae: 0.1324 - val_gender_output_accuracy: 0.8821
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 44/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0513 - age_output_loss: 0.0097 - gender_output_loss: 0.1250 - age_output_mae: 0.0757 - gender_output_accuracy: 0.9532 - val_loss: 0.2483 - val_age_output_loss: 0.0552 - val_gender_output_loss: 0.2757 - val_age_output_mae: 0.1335 - val_gender_output_accuracy: 0.8952
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 45/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0495 - age_output_loss: 0.0094 - gender_output_loss: 0.1180 - age_output_mae: 0.0740 - gender_output_accuracy: 0.9549 - val_loss: 0.1888 - val_age_output_loss: 0.0406 - val_gender_output_loss: 0.2659 - val_age_output_mae: 0.1396 - val_gender_output_accuracy: 0.8992
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 46/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0493 - age_output_loss: 0.0094 - gender_output_loss: 0.1177 - age_output_mae: 0.0740 - gender_output_accuracy: 0.9549 - val_loss: 0.2669 - val_age_output_loss: 0.0587 - val_gender_output_loss: 0.3198 - val_age_output_mae: 0.1837 - val_gender_output_accuracy: 0.8901
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 47/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.0490 - age_output_loss: 0.0092 - gender_output_loss: 0.1201 - age_output_mae: 0.0734 - gender_output_accuracy: 0.9568 - val_loss: 0.2066 - val_age_output_loss: 0.0427 - val_gender_output_loss: 0.3588 - val_age_output_mae: 0.1568 - val_gender_output_accuracy: 0.8839
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 48/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0524 - age_output_loss: 0.0101 - gender_output_loss: 0.1186 - age_output_mae: 0.0754 - gender_output_accuracy: 0.9551 - val_loss: 0.1396 - val_age_output_loss: 0.0274 - val_gender_output_loss: 0.2986 - val_age_output_mae: 0.1052 - val_gender_output_accuracy: 0.8891
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 49/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0485 - age_output_loss: 0.0094 - gender_output_loss: 0.1094 - age_output_mae: 0.0735 - gender_output_accuracy: 0.9602 - val_loss: 0.1318 - val_age_output_loss: 0.0262 - val_gender_output_loss: 0.2683 - val_age_output_mae: 0.1122 - val_gender_output_accuracy: 0.8976
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 50/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0466 - age_output_loss: 0.0088 - gender_output_loss: 0.1120 - age_output_mae: 0.0717 - gender_output_accuracy: 0.9579 - val_loss: 0.1946 - val_age_output_loss: 0.0418 - val_gender_output_loss: 0.2756 - val_age_output_mae: 0.1646 - val_gender_output_accuracy: 0.9006
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 51/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0438 - age_output_loss: 0.0085 - gender_output_loss: 0.0986 - age_output_mae: 0.0705 - gender_output_accuracy: 0.9626 - val_loss: 0.1963 - val_age_output_loss: 0.0420 - val_gender_output_loss: 0.2811 - val_age_output_mae: 0.1573 - val_gender_output_accuracy: 0.8990
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 52/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0448 - age_output_loss: 0.0087 - gender_output_loss: 0.1023 - age_output_mae: 0.0706 - gender_output_accuracy: 0.9626 - val_loss: 0.2256 - val_age_output_loss: 0.0495 - val_gender_output_loss: 0.2748 - val_age_output_mae: 0.1780 - val_gender_output_accuracy: 0.9000
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 53/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.0437 - age_output_loss: 0.0084 - gender_output_loss: 0.1006 - age_output_mae: 0.0696 - gender_output_accuracy: 0.9637 - val_loss: 0.2592 - val_age_output_loss: 0.0560 - val_gender_output_loss: 0.3512 - val_age_output_mae: 0.1938 - val_gender_output_accuracy: 0.8909
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 54/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0425 - age_output_loss: 0.0081 - gender_output_loss: 0.0993 - age_output_mae: 0.0685 - gender_output_accuracy: 0.9638 - val_loss: 0.2564 - val_age_output_loss: 0.0564 - val_gender_output_loss: 0.3093 - val_age_output_mae: 0.1901 - val_gender_output_accuracy: 0.8970
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 55/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0428 - age_output_loss: 0.0083 - gender_output_loss: 0.0949 - age_output_mae: 0.0696 - gender_output_accuracy: 0.9657 - val_loss: 0.3503 - val_age_output_loss: 0.0797 - val_gender_output_loss: 0.3146 - val_age_output_mae: 0.2131 - val_gender_output_accuracy: 0.8966
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 56/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0412 - age_output_loss: 0.0081 - gender_output_loss: 0.0864 - age_output_mae: 0.0689 - gender_output_accuracy: 0.9700 - val_loss: 0.2043 - val_age_output_loss: 0.0437 - val_gender_output_loss: 0.2938 - val_age_output_mae: 0.1719 - val_gender_output_accuracy: 0.8950
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 57/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0408 - age_output_loss: 0.0080 - gender_output_loss: 0.0875 - age_output_mae: 0.0686 - gender_output_accuracy: 0.9644 - val_loss: 0.1717 - val_age_output_loss: 0.0347 - val_gender_output_loss: 0.3294 - val_age_output_mae: 0.1304 - val_gender_output_accuracy: 0.8913
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 58/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0413 - age_output_loss: 0.0081 - gender_output_loss: 0.0905 - age_output_mae: 0.0685 - gender_output_accuracy: 0.9660 - val_loss: 0.2082 - val_age_output_loss: 0.0429 - val_gender_output_loss: 0.3656 - val_age_output_mae: 0.1653 - val_gender_output_accuracy: 0.8899
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 59/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0412 - age_output_loss: 0.0082 - gender_output_loss: 0.0829 - age_output_mae: 0.0689 - gender_output_accuracy: 0.9722 - val_loss: 0.1544 - val_age_output_loss: 0.0305 - val_gender_output_loss: 0.3241 - val_age_output_mae: 0.1310 - val_gender_output_accuracy: 0.8929
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 60/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0397 - age_output_loss: 0.0078 - gender_output_loss: 0.0840 - age_output_mae: 0.0674 - gender_output_accuracy: 0.9697 - val_loss: 0.1355 - val_age_output_loss: 0.0231 - val_gender_output_loss: 0.4287 - val_age_output_mae: 0.1143 - val_gender_output_accuracy: 0.8885
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 61/100
# 362/362 [==============================] - 61s 169ms/step - loss: 0.0383 - age_output_loss: 0.0076 - gender_output_loss: 0.0789 - age_output_mae: 0.0666 - gender_output_accuracy: 0.9733 - val_loss: 0.0954 - val_age_output_loss: 0.0163 - val_gender_output_loss: 0.3014 - val_age_output_mae: 0.0930 - val_gender_output_accuracy: 0.8998
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 62/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0403 - age_output_loss: 0.0081 - gender_output_loss: 0.0807 - age_output_mae: 0.0680 - gender_output_accuracy: 0.9733 - val_loss: 0.0838 - val_age_output_loss: 0.0112 - val_gender_output_loss: 0.3919 - val_age_output_mae: 0.0692 - val_gender_output_accuracy: 0.8897
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 63/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0397 - age_output_loss: 0.0079 - gender_output_loss: 0.0810 - age_output_mae: 0.0673 - gender_output_accuracy: 0.9720 - val_loss: 0.1051 - val_age_output_loss: 0.0143 - val_gender_output_loss: 0.4804 - val_age_output_mae: 0.0824 - val_gender_output_accuracy: 0.8810
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 64/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0401 - age_output_loss: 0.0080 - gender_output_loss: 0.0821 - age_output_mae: 0.0677 - gender_output_accuracy: 0.9702 - val_loss: 0.0853 - val_age_output_loss: 0.0132 - val_gender_output_loss: 0.3246 - val_age_output_mae: 0.0854 - val_gender_output_accuracy: 0.8935
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 65/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0387 - age_output_loss: 0.0078 - gender_output_loss: 0.0760 - age_output_mae: 0.0666 - gender_output_accuracy: 0.9738 - val_loss: 0.0858 - val_age_output_loss: 0.0133 - val_gender_output_loss: 0.3262 - val_age_output_mae: 0.0684 - val_gender_output_accuracy: 0.8986
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 66/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0386 - age_output_loss: 0.0078 - gender_output_loss: 0.0761 - age_output_mae: 0.0673 - gender_output_accuracy: 0.9727 - val_loss: 0.0662 - val_age_output_loss: 0.0091 - val_gender_output_loss: 0.2969 - val_age_output_mae: 0.0680 - val_gender_output_accuracy: 0.9010
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 67/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0372 - age_output_loss: 0.0076 - gender_output_loss: 0.0701 - age_output_mae: 0.0656 - gender_output_accuracy: 0.9747 - val_loss: 0.1151 - val_age_output_loss: 0.0210 - val_gender_output_loss: 0.3103 - val_age_output_mae: 0.1065 - val_gender_output_accuracy: 0.8976
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 68/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0369 - age_output_loss: 0.0075 - gender_output_loss: 0.0694 - age_output_mae: 0.0663 - gender_output_accuracy: 0.9769 - val_loss: 0.0682 - val_age_output_loss: 0.0092 - val_gender_output_loss: 0.3120 - val_age_output_mae: 0.0717 - val_gender_output_accuracy: 0.8996
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 69/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0373 - age_output_loss: 0.0076 - gender_output_loss: 0.0705 - age_output_mae: 0.0666 - gender_output_accuracy: 0.9758 - val_loss: 0.0722 - val_age_output_loss: 0.0093 - val_gender_output_loss: 0.3511 - val_age_output_mae: 0.0735 - val_gender_output_accuracy: 0.8944
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 70/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0364 - age_output_loss: 0.0074 - gender_output_loss: 0.0689 - age_output_mae: 0.0656 - gender_output_accuracy: 0.9766 - val_loss: 0.0651 - val_age_output_loss: 0.0080 - val_gender_output_loss: 0.3323 - val_age_output_mae: 0.0672 - val_gender_output_accuracy: 0.8978
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 71/100
# 362/362 [==============================] - 62s 170ms/step - loss: 0.0402 - age_output_loss: 0.0082 - gender_output_loss: 0.0735 - age_output_mae: 0.0661 - gender_output_accuracy: 0.9732 - val_loss: 0.0723 - val_age_output_loss: 0.0101 - val_gender_output_loss: 0.3192 - val_age_output_mae: 0.0766 - val_gender_output_accuracy: 0.9002
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 72/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0358 - age_output_loss: 0.0071 - gender_output_loss: 0.0718 - age_output_mae: 0.0644 - gender_output_accuracy: 0.9737 - val_loss: 0.0731 - val_age_output_loss: 0.0087 - val_gender_output_loss: 0.3835 - val_age_output_mae: 0.0706 - val_gender_output_accuracy: 0.8863
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 73/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0350 - age_output_loss: 0.0071 - gender_output_loss: 0.0647 - age_output_mae: 0.0646 - gender_output_accuracy: 0.9760 - val_loss: 0.0810 - val_age_output_loss: 0.0082 - val_gender_output_loss: 0.4811 - val_age_output_mae: 0.0696 - val_gender_output_accuracy: 0.8853
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 74/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0349 - age_output_loss: 0.0071 - gender_output_loss: 0.0668 - age_output_mae: 0.0642 - gender_output_accuracy: 0.9765 - val_loss: 0.0655 - val_age_output_loss: 0.0085 - val_gender_output_loss: 0.3166 - val_age_output_mae: 0.0687 - val_gender_output_accuracy: 0.8956
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 75/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0343 - age_output_loss: 0.0071 - gender_output_loss: 0.0611 - age_output_mae: 0.0641 - gender_output_accuracy: 0.9796 - val_loss: 0.0719 - val_age_output_loss: 0.0084 - val_gender_output_loss: 0.3821 - val_age_output_mae: 0.0681 - val_gender_output_accuracy: 0.8923
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 76/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0325 - age_output_loss: 0.0066 - gender_output_loss: 0.0598 - age_output_mae: 0.0624 - gender_output_accuracy: 0.9795 - val_loss: 0.0672 - val_age_output_loss: 0.0079 - val_gender_output_loss: 0.3543 - val_age_output_mae: 0.0675 - val_gender_output_accuracy: 0.8984
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 77/100
# 362/362 [==============================] - 61s 170ms/step - loss: 0.0328 - age_output_loss: 0.0066 - gender_output_loss: 0.0633 - age_output_mae: 0.0623 - gender_output_accuracy: 0.9765 - val_loss: 0.0667 - val_age_output_loss: 0.0076 - val_gender_output_loss: 0.3628 - val_age_output_mae: 0.0638 - val_gender_output_accuracy: 0.8954
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 78/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0331 - age_output_loss: 0.0066 - gender_output_loss: 0.0650 - age_output_mae: 0.0620 - gender_output_accuracy: 0.9771 - val_loss: 0.1091 - val_age_output_loss: 0.0177 - val_gender_output_loss: 0.3844 - val_age_output_mae: 0.0756 - val_gender_output_accuracy: 0.8925
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 79/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0322 - age_output_loss: 0.0066 - gender_output_loss: 0.0588 - age_output_mae: 0.0621 - gender_output_accuracy: 0.9798 - val_loss: 0.0738 - val_age_output_loss: 0.0103 - val_gender_output_loss: 0.3255 - val_age_output_mae: 0.0800 - val_gender_output_accuracy: 0.8990
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 80/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0329 - age_output_loss: 0.0067 - gender_output_loss: 0.0623 - age_output_mae: 0.0623 - gender_output_accuracy: 0.9769 - val_loss: 0.0669 - val_age_output_loss: 0.0073 - val_gender_output_loss: 0.3770 - val_age_output_mae: 0.0638 - val_gender_output_accuracy: 0.8942
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 81/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0319 - age_output_loss: 0.0066 - gender_output_loss: 0.0535 - age_output_mae: 0.0621 - gender_output_accuracy: 0.9796 - val_loss: 0.0886 - val_age_output_loss: 0.0124 - val_gender_output_loss: 0.3898 - val_age_output_mae: 0.0902 - val_gender_output_accuracy: 0.8921
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 82/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0313 - age_output_loss: 0.0065 - gender_output_loss: 0.0551 - age_output_mae: 0.0616 - gender_output_accuracy: 0.9799 - val_loss: 0.0740 - val_age_output_loss: 0.0092 - val_gender_output_loss: 0.3733 - val_age_output_mae: 0.0654 - val_gender_output_accuracy: 0.8915
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 83/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0304 - age_output_loss: 0.0063 - gender_output_loss: 0.0501 - age_output_mae: 0.0611 - gender_output_accuracy: 0.9822 - val_loss: 0.0936 - val_age_output_loss: 0.0151 - val_gender_output_loss: 0.3326 - val_age_output_mae: 0.0946 - val_gender_output_accuracy: 0.9004
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 84/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0308 - age_output_loss: 0.0064 - gender_output_loss: 0.0526 - age_output_mae: 0.0610 - gender_output_accuracy: 0.9822 - val_loss: 0.0829 - val_age_output_loss: 0.0119 - val_gender_output_loss: 0.3536 - val_age_output_mae: 0.0661 - val_gender_output_accuracy: 0.8940
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 85/100
# 362/362 [==============================] - 62s 171ms/step - loss: 0.0306 - age_output_loss: 0.0063 - gender_output_loss: 0.0550 - age_output_mae: 0.0609 - gender_output_accuracy: 0.9811 - val_loss: 0.4853 - val_age_output_loss: 0.1130 - val_gender_output_loss: 0.3351 - val_age_output_mae: 0.0927 - val_gender_output_accuracy: 0.8990
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 86/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0306 - age_output_loss: 0.0063 - gender_output_loss: 0.0535 - age_output_mae: 0.0606 - gender_output_accuracy: 0.9803 - val_loss: 0.1176 - val_age_output_loss: 0.0210 - val_gender_output_loss: 0.3360 - val_age_output_mae: 0.0703 - val_gender_output_accuracy: 0.9024
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 87/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0314 - age_output_loss: 0.0065 - gender_output_loss: 0.0558 - age_output_mae: 0.0613 - gender_output_accuracy: 0.9802 - val_loss: 0.0900 - val_age_output_loss: 0.0126 - val_gender_output_loss: 0.3966 - val_age_output_mae: 0.0688 - val_gender_output_accuracy: 0.8933
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 88/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0300 - age_output_loss: 0.0062 - gender_output_loss: 0.0523 - age_output_mae: 0.0605 - gender_output_accuracy: 0.9815 - val_loss: 0.0774 - val_age_output_loss: 0.0107 - val_gender_output_loss: 0.3453 - val_age_output_mae: 0.0659 - val_gender_output_accuracy: 0.8974
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 89/100
# 362/362 [==============================] - 62s 173ms/step - loss: 0.0295 - age_output_loss: 0.0062 - gender_output_loss: 0.0472 - age_output_mae: 0.0604 - gender_output_accuracy: 0.9846 - val_loss: 0.0761 - val_age_output_loss: 0.0105 - val_gender_output_loss: 0.3424 - val_age_output_mae: 0.0664 - val_gender_output_accuracy: 0.8976
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 90/100
# 362/362 [==============================] - 62s 173ms/step - loss: 0.0288 - age_output_loss: 0.0061 - gender_output_loss: 0.0441 - age_output_mae: 0.0597 - gender_output_accuracy: 0.9863 - val_loss: 0.0652 - val_age_output_loss: 0.0078 - val_gender_output_loss: 0.3402 - val_age_output_mae: 0.0626 - val_gender_output_accuracy: 0.9006
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 91/100
# 362/362 [==============================] - 62s 173ms/step - loss: 0.0299 - age_output_loss: 0.0061 - gender_output_loss: 0.0564 - age_output_mae: 0.0600 - gender_output_accuracy: 0.9785 - val_loss: 0.0815 - val_age_output_loss: 0.0120 - val_gender_output_loss: 0.3343 - val_age_output_mae: 0.0649 - val_gender_output_accuracy: 0.8974
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 92/100
# 362/362 [==============================] - 63s 173ms/step - loss: 0.0291 - age_output_loss: 0.0060 - gender_output_loss: 0.0491 - age_output_mae: 0.0599 - gender_output_accuracy: 0.9827 - val_loss: 0.0887 - val_age_output_loss: 0.0121 - val_gender_output_loss: 0.4046 - val_age_output_mae: 0.0655 - val_gender_output_accuracy: 0.8907
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 93/100
# 362/362 [==============================] - 62s 173ms/step - loss: 0.0304 - age_output_loss: 0.0064 - gender_output_loss: 0.0483 - age_output_mae: 0.0614 - gender_output_accuracy: 0.9833 - val_loss: 0.1132 - val_age_output_loss: 0.0193 - val_gender_output_loss: 0.3598 - val_age_output_mae: 0.0715 - val_gender_output_accuracy: 0.8972
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 94/100
# 362/362 [==============================] - 63s 174ms/step - loss: 0.0277 - age_output_loss: 0.0059 - gender_output_loss: 0.0408 - age_output_mae: 0.0591 - gender_output_accuracy: 0.9867 - val_loss: 0.0649 - val_age_output_loss: 0.0071 - val_gender_output_loss: 0.3643 - val_age_output_mae: 0.0621 - val_gender_output_accuracy: 0.9020
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 95/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0287 - age_output_loss: 0.0060 - gender_output_loss: 0.0465 - age_output_mae: 0.0592 - gender_output_accuracy: 0.9835 - val_loss: 0.0688 - val_age_output_loss: 0.0070 - val_gender_output_loss: 0.4068 - val_age_output_mae: 0.0621 - val_gender_output_accuracy: 0.8935
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 96/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0291 - age_output_loss: 0.0061 - gender_output_loss: 0.0451 - age_output_mae: 0.0602 - gender_output_accuracy: 0.9832 - val_loss: 0.0652 - val_age_output_loss: 0.0070 - val_gender_output_loss: 0.3730 - val_age_output_mae: 0.0610 - val_gender_output_accuracy: 0.8964
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 97/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0281 - age_output_loss: 0.0060 - gender_output_loss: 0.0394 - age_output_mae: 0.0594 - gender_output_accuracy: 0.9865 - val_loss: 0.0879 - val_age_output_loss: 0.0126 - val_gender_output_loss: 0.3741 - val_age_output_mae: 0.0813 - val_gender_output_accuracy: 0.8970
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 98/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0282 - age_output_loss: 0.0060 - gender_output_loss: 0.0415 - age_output_mae: 0.0595 - gender_output_accuracy: 0.9849 - val_loss: 0.3374 - val_age_output_loss: 0.0751 - val_gender_output_loss: 0.3679 - val_age_output_mae: 0.1063 - val_gender_output_accuracy: 0.9018
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 99/100
# 362/362 [==============================] - 62s 172ms/step - loss: 0.0282 - age_output_loss: 0.0059 - gender_output_loss: 0.0440 - age_output_mae: 0.0589 - gender_output_accuracy: 0.9835 - val_loss: 0.0637 - val_age_output_loss: 0.0069 - val_gender_output_loss: 0.3616 - val_age_output_mae: 0.0610 - val_gender_output_accuracy: 0.8972
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets
# Epoch 100/100
# 362/362 [==============================] - 62s 173ms/step - loss: 0.0265 - age_output_loss: 0.0056 - gender_output_loss: 0.0417 - age_output_mae: 0.0573 - gender_output_accuracy: 0.9864 - val_loss: 0.0698 - val_age_output_loss: 0.0083 - val_gender_output_loss: 0.3661 - val_age_output_mae: 0.0617 - val_gender_output_accuracy: 0.9012
# INFO:tensorflow:Assets written to: ./model_checkpoint/assets

# %%
plt.clf()

fig = go.Figure()
fig.add_trace(go.Scatter(
                    y=history.history['gender_output_accuracy'],
                    name='Train'))

fig.add_trace(go.Scatter(
                    y=history.history['val_gender_output_accuracy'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Accuracy for gender feature',
                  xaxis_title='Epoch',
                  yaxis_title='Accuracy')

fig.write_html('acc_gender.html', include_plotlyjs='cdn')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6ce6ade4-4f0b-4d0c-993e-cb64ca0b14f0" class="plotly-graph-div" style="height:450px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6ce6ade4-4f0b-4d0c-993e-cb64ca0b14f0")) {
#                     Plotly.newPlot(
#                         '6ce6ade4-4f0b-4d0c-993e-cb64ca0b14f0',
#                         [{"name": "Train", "type": "scatter", "y": [0.7408494353294373, 0.8047306537628174, 0.8246719837188721, 0.845735490322113, 0.847461998462677, 0.8568715453147888, 0.8624827265739441, 0.869561493396759, 0.8733597993850708, 0.8755179643630981, 0.8789709806442261, 0.8832009434700012, 0.8857907652854919, 0.8879488706588745, 0.8926967978477478, 0.892610490322113, 0.8987396359443665, 0.8975310921669006, 0.8996891975402832, 0.9064226746559143, 0.9115158915519714, 0.909098744392395, 0.911688506603241, 0.9189398884773254, 0.9186809659004211, 0.9186809659004211, 0.9235152006149292, 0.925586998462677, 0.9277451634407043, 0.9305076003074646, 0.93180251121521, 0.9373273253440857, 0.9387949109077454, 0.9402624368667603, 0.9388812184333801, 0.942938506603241, 0.9425932168960571, 0.9471685290336609, 0.9451830387115479, 0.9493266344070435, 0.951139509677887, 0.9483770728111267, 0.9536429643630981, 0.9528660178184509, 0.9539019465446472, 0.9561464190483093, 0.958563506603241, 0.953988254070282, 0.9597721099853516, 0.9602037072181702, 0.9616712927818298, 0.9642610549926758, 0.9634841084480286, 0.963311493396759, 0.967627763748169, 0.9686636924743652, 0.9665918350219727, 0.9677140712738037, 0.9700449109077454, 0.969613254070282, 0.9717714190483093, 0.9734979271888733, 0.9703038930892944, 0.9716851115226746, 0.9729799628257751, 0.9738432168960571, 0.9759150743484497, 0.9760013818740845, 0.9758287072181702, 0.9760013818740845, 0.9728936553001404, 0.9732389450073242, 0.9749654531478882, 0.9766919612884521, 0.9783321619033813, 0.9773826003074646, 0.9763466715812683, 0.9757423996925354, 0.9788501262664795, 0.9788501262664795, 0.9783321619033813, 0.9795407652854919, 0.9829937815666199, 0.9795407652854919, 0.9818715453147888, 0.9800587296485901, 0.9798860549926758, 0.9833390712738037, 0.9828211069107056, 0.9846339821815491, 0.9810945987701416, 0.9838570356369019, 0.9838570356369019, 0.9849792718887329, 0.982648491859436, 0.9845476746559143, 0.9851519465446472, 0.9835980534553528, 0.9830800890922546, 0.9860152006149292]}, {"name": "Valid", "type": "scatter", "y": [0.7407258152961731, 0.819556474685669, 0.8131048679351807, 0.8020161390304565, 0.8243951797485352, 0.8324596881866455, 0.8491935729980469, 0.8455645442008972, 0.8423386812210083, 0.8536290526390076, 0.8409274220466614, 0.8471774458885193, 0.8653225898742676, 0.882056474685669, 0.88286292552948, 0.8832661509513855, 0.8887096643447876, 0.8877016305923462, 0.8897177577018738, 0.8816532492637634, 0.8929435610771179, 0.8891128897666931, 0.8917338848114014, 0.8889113068580627, 0.8909274339675903, 0.8931451439857483, 0.8959677219390869, 0.8985887169837952, 0.8957661390304565, 0.896774172782898, 0.8893145322799683, 0.8955644965171814, 0.8963709473609924, 0.8907257914543152, 0.8985887169837952, 0.8913306593894958, 0.9020161032676697, 0.8895161151885986, 0.893750011920929, 0.8973790407180786, 0.8893145322799683, 0.8911290168762207, 0.882056474685669, 0.8951612710952759, 0.899193525314331, 0.8901209831237793, 0.8838709592819214, 0.8891128897666931, 0.897580623626709, 0.9006048440933228, 0.8989919424057007, 0.8999999761581421, 0.8909274339675903, 0.8969758152961731, 0.8965725898742676, 0.8949596881866455, 0.8913306593894958, 0.8899193406105042, 0.8929435610771179, 0.8885080814361572, 0.8997983932495117, 0.8897177577018738, 0.8810483813285828, 0.8935483694076538, 0.8985887169837952, 0.9010080695152283, 0.897580623626709, 0.8995967507362366, 0.8943548202514648, 0.8977822661399841, 0.9002016186714172, 0.8862903118133545, 0.8852822780609131, 0.8955644965171814, 0.8923386931419373, 0.89838707447052, 0.895362913608551, 0.8925403356552124, 0.8989919424057007, 0.8941532373428345, 0.8921371102333069, 0.8915322422981262, 0.9004032015800476, 0.8939515948295593, 0.8989919424057007, 0.9024193286895752, 0.8933467864990234, 0.8973790407180786, 0.897580623626709, 0.9006048440933228, 0.8973790407180786, 0.8907257914543152, 0.8971773982048035, 0.9020161032676697, 0.8935483694076538, 0.8963709473609924 ...
#                         {"height": 450, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoord

# %%
plt.clf()

fig = go.Figure()
fig.add_trace(go.Scattergl(
                    y=history.history['age_output_mae'],
                    name='Train'))

fig.add_trace(go.Scattergl(
                    y=history.history['val_age_output_mae'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Mean Absolute Error for age feature',
                  xaxis_title='Epoch',
                  yaxis_title='Mean Absolute Error')

fig.write_html('mae_age.html', include_plotlyjs='cdn')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43d56556-4977-4e16-aa0f-0a8cf01c662c" class="plotly-graph-div" style="height:450px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43d56556-4977-4e16-aa0f-0a8cf01c662c")) {
#                     Plotly.newPlot(
#                         '43d56556-4977-4e16-aa0f-0a8cf01c662c',
#                         [{"name": "Train", "type": "scattergl", "y": [1.1757630109786987, 0.885044515132904, 0.7763624787330627, 0.685860276222229, 0.6080718636512756, 0.5380322933197021, 0.47921663522720337, 0.43105635046958923, 0.37695983052253723, 0.33092087507247925, 0.2895886301994324, 0.25525978207588196, 0.22116506099700928, 0.19535709917545319, 0.169962540268898, 0.1511901170015335, 0.13540805876255035, 0.12379254400730133, 0.11243461072444916, 0.10550601035356522, 0.10125508904457092, 0.09820050746202469, 0.09531199932098389, 0.09321149438619614, 0.0918632224202156, 0.09142743796110153, 0.08921603113412857, 0.08774932473897934, 0.08640572428703308, 0.08604453504085541, 0.08521361649036407, 0.08360378444194794, 0.0830545723438263, 0.08143138140439987, 0.08034761995077133, 0.08006685227155685, 0.078513503074646, 0.07725068926811218, 0.07747678458690643, 0.07720819860696793, 0.07594034820795059, 0.07550417631864548, 0.07422381639480591, 0.07391320914030075, 0.07278449833393097, 0.07232461869716644, 0.07232638448476791, 0.07470662891864777, 0.07190336287021637, 0.07056092470884323, 0.06972534954547882, 0.07034149765968323, 0.06895074993371964, 0.06829291582107544, 0.06877169013023376, 0.06855731457471848, 0.06813039630651474, 0.06778605282306671, 0.067982517182827, 0.06686090677976608, 0.06606429070234299, 0.06707786023616791, 0.0665837898850441, 0.06703075021505356, 0.06630772352218628, 0.06652621179819107, 0.06526429206132889, 0.06562703847885132, 0.06533805280923843, 0.0647212341427803, 0.0648365244269371, 0.06365932524204254, 0.0640881136059761, 0.06441061198711395, 0.06344900280237198, 0.06235956773161888, 0.06287521868944168, 0.06236715614795685, 0.061783578246831894, 0.06196398288011551, 0.062171898782253265, 0.06159074977040291, 0.061050377786159515, 0.06117810681462288, 0.06127046048641205, 0.06033439561724663, 0.060810741037130356, 0.05979292839765549, 0.05999220162630081, 0.059877004474401474, 0.059654008597135544, 0.059963591396808624, 0.060355618596076965, 0.058816131204366684, 0.05917498096823692, 0.059936754405498505, 0.05902678146958351, 0.059688400477170944, 0.05913025885820389, 0.057754646986722946]}, {"name": "Valid", "type": "scattergl", "y": [2.4529638290405273, 1.5787118673324585, 0.9730104804039001, 0.9550782442092896, 1.0079556703567505, 0.6501867175102234, 0.4765608608722687, 0.4837739169597626, 0.497463196516037, 0.4502497613430023, 0.5542691349983215, 0.5789933800697327, 0.4231319725513458, 0.5592376589775085, 0.4059833884239197, 0.3517290949821472, 0.34319883584976196, 0.32896536588668823, 0.3028746247291565, 0.17912183701992035, 0.1983398050069809, 0.19508975744247437, 0.18339352309703827, 0.20927079021930695, 0.1708526462316513, 0.16835398972034454, 0.15565402805805206, 0.1236901581287384, 0.11803870648145676, 0.12475725263357162, 0.13008786737918854, 0.10580761730670929, 0.12092340737581253, 0.10179223865270615, 0.10208425670862198, 0.12021440267562866, 0.1131778210401535, 0.09531920403242111, 0.12219638377428055, 0.09031492471694946, 0.14746636152267456, 0.14073005318641663, 0.132355198264122, 0.1334599256515503, 0.13963472843170166, 0.18367664515972137, 0.1568363904953003, 0.10517186671495438, 0.11215955764055252, 0.164568230509758, 0.15725740790367126, 0.17796266078948975, 0.19378450512886047, 0.1900726556777954, 0.21311749517917633, 0.17189735174179077, 0.13041247427463531, 0.1653089076280594, 0.13101546466350555, 0.11428899317979813, 0.09298470616340637, 0.06920632719993591, 0.08241331577301025, 0.08542639017105103, 0.06838777661323547, 0.06796981394290924, 0.1064656674861908, 0.07168853282928467, 0.07349501550197601, 0.06717970222234726, 0.0765766054391861, 0.070585235953331, 0.06955134868621826, 0.06870970875024796, 0.0681479275226593, 0.06753484159708023, 0.06376830488443375, 0.0756361335515976, 0.08002546429634094, 0.06375636160373688, 0.09015852957963943, 0.06544969975948334, 0.09456858783960342, 0.06607387214899063, 0.0926748588681221, 0.07027850300073624, 0.06875377148389816, 0.0 ...
#                         {"height": 450, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777

# %%
fig = go.Figure()
fig.add_trace(go.Scattergl(
                    y=history.history['loss'],
                    name='Train'))

fig.add_trace(go.Scattergl(
                    y=history.history['val_loss'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Overall loss',
                  xaxis_title='Epoch',
                  yaxis_title='Loss')

fig.write_html('overall_loss.html', include_plotlyjs='cdn')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cd55cce9-a342-40da-b94e-fadf175f0dc0" class="plotly-graph-div" style="height:450px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd55cce9-a342-40da-b94e-fadf175f0dc0")) {
#                     Plotly.newPlot(
#                         'cd55cce9-a342-40da-b94e-fadf175f0dc0',
#                         [{"name": "Train", "type": "scattergl", "y": [9.228038787841797, 5.434248447418213, 4.334722518920898, 3.340932846069336, 2.630110502243042, 2.1181800365448, 1.6833817958831787, 1.395426869392395, 1.0609935522079468, 0.8172997832298279, 0.6376093029975891, 0.4962385892868042, 0.3753453493118286, 0.2983364164829254, 0.22790369391441345, 0.1821553111076355, 0.14894942939281464, 0.12802504003047943, 0.10958348959684372, 0.0998072475194931, 0.09160641580820084, 0.08785158395767212, 0.08366496115922928, 0.08048103749752045, 0.07829271256923676, 0.07705692201852798, 0.07367488741874695, 0.07179205864667892, 0.0700952336192131, 0.06856419146060944, 0.06788689643144608, 0.06519973278045654, 0.0637011006474495, 0.06120087578892708, 0.060231324285268784, 0.059040334075689316, 0.057299427688121796, 0.05578682944178581, 0.055878397077322006, 0.05421464517712593, 0.053032584488391876, 0.0525689460337162, 0.05063755065202713, 0.05006595700979233, 0.04860047996044159, 0.04777359962463379, 0.0474017858505249, 0.05171899497509003, 0.04651045799255371, 0.0451875776052475, 0.04340425506234169, 0.044146306812763214, 0.042898714542388916, 0.04273076727986336, 0.042008038610219955, 0.041320424526929855, 0.040670640766620636, 0.040434256196022034, 0.040397439152002335, 0.03934952989220619, 0.0381811186671257, 0.038980137556791306, 0.038637127727270126, 0.038757652044296265, 0.03793259710073471, 0.03765735402703285, 0.036439199000597, 0.03628239035606384, 0.036125920712947845, 0.03542818874120712, 0.03706370294094086, 0.0349004790186882, 0.034810516983270645, 0.03487183153629303, 0.033711373805999756, 0.03281600773334503, 0.03318265825510025, 0.033495862036943436, 0.03207477927207947, 0.03206288442015648, 0.03189508989453316, 0.031103992834687233, 0.03016560897231102, 0.03106400929391384, 0.031001949682831764, 0.030124850571155548, 0.030772998929023743, 0.028845813125371933, 0.029317766427993774, 0.02918952889740467, 0.02928626909852028, 0.02894751727581024, 0.029270272701978683, 0.02782144583761692, 0.028708552941679955, 0.028629519045352936, 0.028064053505659103, 0.02848266437649727, 0.02830018475651741, 0.026766465976834297]}, {"name": "Valid", "type": "scattergl", "y": [29.105300903320312, 23.51630401611328, 18.093263626098633, 19.165729522705078, 21.005475997924805, 11.081235885620117, 5.978124618530273, 6.6448564529418945, 7.426861763000488, 6.412087917327881, 10.047730445861816, 11.366618156433105, 6.313795566558838, 8.380465507507324, 5.430986404418945, 4.499921798706055, 4.401340007781982, 4.158952713012695, 3.7246663570404053, 1.1762375831604004, 1.4994572401046753, 1.4203660488128662, 1.1598831415176392, 1.3754702806472778, 0.8192668557167053, 1.0175930261611938, 0.7892947196960449, 0.5427550077438354, 0.44403937458992004, 0.4787013828754425, 0.7486864328384399, 0.3590080738067627, 0.451434463262558, 0.3871125876903534, 0.28413835167884827, 0.42217329144477844, 0.4811849296092987, 0.2625608444213867, 0.3831351399421692, 0.21945582330226898, 0.33145520091056824, 0.3863896131515503, 0.6535519957542419, 0.24827462434768677, 0.1888473480939865, 0.2668912708759308, 0.20658186078071594, 0.13958847522735596, 0.13176798820495605, 0.19462360441684723, 0.19625751674175262, 0.22559349238872528, 0.25924891233444214, 0.2563692629337311, 0.3503185510635376, 0.20429225265979767, 0.17170843482017517, 0.20816807448863983, 0.1544244885444641, 0.13545683026313782, 0.09537762403488159, 0.08383116871118546, 0.10505185276269913, 0.0853128582239151, 0.08579236268997192, 0.06622044742107391, 0.1150616928935051, 0.06816679239273071, 0.07215660065412521, 0.06506108492612839, 0.07233478873968124, 0.07310063391923904, 0.08103006333112717, 0.06548967212438583, 0.0718521848320961, 0.06719660758972168, 0.06670500338077545, 0.10913308709859848, 0.0738230049610138, 0.066947340965271, 0.08857747912406921, 0.07404403388500214, 0.09359830617904663, 0.08286192268133163, 0.4853264093399048, 0.11758725345134735, 0.08998039364814758, 0.07744330167770386,  ...
#                         {"height": 450, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0

# %%
test_batch_size = 128
test_generator = data_generator.generate_images(test_idx, is_training=False, batch_size=test_batch_size)
age_pred, gender_pred = model.predict_generator(test_generator, 
                                                           steps=len(test_idx)//test_batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning:
#
# `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.

# %%
test_generator = data_generator.generate_images(test_idx, is_training=False, batch_size=test_batch_size)
samples = 0
images, age_true, gender_true = [], [], []
for test_batch in test_generator:
    image = test_batch[0]
    labels = test_batch[1]
    
    images.extend(image)
    age_true.extend(labels[0])
    gender_true.extend(labels[1])
    
age_true = np.array(age_true)
gender_true = np.array(gender_true)

gender_true =  gender_true.argmax(axis=-1)
gender_pred =  gender_pred.argmax(axis=-1)

print(data_generator.max_age)

age_true = age_true * data_generator.max_age
age_pred = age_pred * data_generator.max_age
# Out:
# 116.0

# %%
from sklearn.metrics import classification_report
cr_gender = classification_report(gender_true, gender_pred, target_names=dataset_dict['gender_alias'].keys())
print(cr_gender)
# Out:
#               precision    recall  f1-score   support
#
#         male       0.91      0.89      0.90      3672
#       female       0.89      0.90      0.89      3368
#
#     accuracy                           0.90      7040
#    macro avg       0.90      0.90      0.90      7040
# weighted avg       0.90      0.90      0.90      7040

# %%
from sklearn.metrics import r2_score

print('R2 score for age: ', r2_score(age_true, age_pred))
# Out:
# R2 score for age:  0.6382149952907382

# %%
import math
n = 16
random_indices = np.random.permutation(n)
n_cols = 4
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 17))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(images[img_idx])
    
    cur_age_pred = age_pred[img_idx]
    cur_age_true = age_true[img_idx]
    
    cur_gender_pred = gender_pred[img_idx]
    cur_gender_true = gender_true[img_idx]

    age_threshold = 10
    if cur_gender_pred == cur_gender_true and  abs(cur_age_pred - cur_age_true) <= age_threshold:
        ax.xaxis.label.set_color('green')
    elif cur_gender_pred != cur_gender_true and  abs(cur_age_pred - cur_age_true) > age_threshold:
        ax.xaxis.label.set_color('red')
    
    ax.set_xlabel('a: {}, g: {}'.format(int(age_pred[img_idx]),
                            dataset_dict['gender_id'][gender_pred[img_idx]]))
    
    ax.set_title('a: {}, g: {}'.format(int(age_true[img_idx]),
                            dataset_dict['gender_id'][gender_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
    
plt.tight_layout()
plt.savefig('preds.png')

# %%
model.save('h5model.h5')

# %%
h5model = tf.keras.models.load_model('h5model.h5')

# Show the model architecture
h5model.summary()
# Out:
# Model: "face_net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 198, 198, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 198, 198, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 198, 198, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 198, 198, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 198, 198, 16) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 198, 198, 16) 64          activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 198, 198, 16) 64          activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 66, 66, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 66, 66, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 66, 66, 16)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 66, 66, 16)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 66, 66, 32)   4640        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 66, 66, 32)   4640        dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 66, 66, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 66, 66, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 66, 66, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 66, 66, 32)   128         activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 33, 33, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 33, 33, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 33, 33, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 33, 33, 32)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 33, 33, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 33, 33, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 33, 33, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 33, 33, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 33, 33, 32)   128         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 33, 33, 32)   128         activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           dropout_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1048704     flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1048704     flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128)          512         activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            258         dropout_7[0][0]
# __________________________________________________________________________________________________
# age_output (Activation)         (None, 1)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# gender_output (Activation)      (None, 2)            0           dense_3[0][0]
# ==================================================================================================
# Total params: 2,128,131
# Trainable params: 2,127,299
# Non-trainable params: 832
# __________________________________________________________________________________________________

# %%
tf.saved_model.save(model, './chekka/')
# Out:
# INFO:tensorflow:Assets written to: ./chekka/assets
